# %% [markdown]
# # Explore here

# %%
import os
import pandas as pd
from dotenv import load_dotenv

# load the .env file variables
load_dotenv()

client_id = os.environ.get('client_id')
client_secret = os.environ.get('client_secret')

# %%
# Importo los paquetes de la api
# Indico las credenciales de conexión a mi api

import spotipy
from spotipy.oauth2 import SpotifyClientCredentials

con = SpotifyClientCredentials(client_id = client_id, client_secret = client_secret)

sp = spotipy.Spotify(client_credentials_manager=con)

# %%
# Selecciono el ID del artista

artist_id = "3UisMJOlCgjdKYysGAJ4b6"

# Tomo las 10 canciones de mayor popularidad
artist_id = artist_id
top_tracks = sp.artist_top_tracks(artist_id)
print (top_tracks)
# Out:
# {'tracks': [{'album': {'album_type': 'album', 'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3UisMJOlCgjdKYysGAJ4b6'}, 'href': 'https://api.spotify.com/v1/artists/3UisMJOlCgjdKYysGAJ4b6', 'id': '3UisMJOlCgjdKYysGAJ4b6', 'name': 'Abuela Coca', 'type': 'artist', 'uri': 'spotify:artist:3UisMJOlCgjdKYysGAJ4b6'}], 'available_markets': ['AR', 'AU', 'AT', 'BE', 'BO', 'BR', 'BG', 'CA', 'CL', 'CO', 'CR', 'CY', 'CZ', 'DK', 'DO', 'DE', 'EC', 'EE', 'SV', 'FI', 'FR', 'GR', 'GT', 'HN', 'HK', 'HU', 'IS', 'IE', 'IT', 'LV', 'LT', 'LU', 'MY', 'MT', 'MX', 'NL', 'NZ', 'NI', 'NO', 'PA', 'PY', 'PE', 'PH', 'PL', 'PT', 'SG', 'SK', 'ES', 'SE', 'CH', 'TW', 'TR', 'UY', 'US', 'GB', 'AD', 'LI', 'MC', 'ID', 'JP', 'TH', 'VN', 'RO', 'IL', 'ZA', 'SA', 'AE', 'BH', 'QA', 'OM', 'KW', 'EG', 'MA', 'DZ', 'TN', 'LB', 'JO', 'PS', 'IN', 'BY', 'KZ', 'MD', 'UA', 'AL', 'BA', 'HR', 'MK', 'SI', 'KR', 'BD', 'PK', 'LK', 'GH', 'KE', 'NG', 'TZ', 'UG', 'AG', 'AM', 'BS', 'BB', 'BZ', 'BT', 'BW', 'BF', 'CV', '
# ...

# %%
# Transformo el "dict" a base de datos

import pandas as pd

tracks_df = pd.DataFrame(tracks)
tracks_df = tracks_df.sort_values ('duration_ms', ascending=False)
print (tracks_df)
# Out:
#    duration_ms                 name  popularity
# 1     5.380883   Se duerme otra vez          28
# 7     4.914433   Se Duerme Otra Vez          22
# 3     4.835067         Asesinos son          26
# 2     4.286433              Walking          26
# 9     4.052217        Mala Herencia          21
# 0     4.049317  El ritmo del barrio          30
# 5     4.017767             Ta Salao          22
# 6     3.862433                  007          22
# 4     3.795333  El Ritmo del Barrio          24
# 8     3.609300               Templo          21

# %%
# Gráfico la relación entre popularidad y duración

import matplotlib.pyplot as plt

plt.scatter(data = tracks_df, x = "popularity", y = "duration_ms", c = 'red')
fig = scatter_plot.get_figure()
fig.savefig("scatter_plot.png")

# %%
# Calculo la correlación de ambas variables

sub_df = tracks_df[['popularity', 'duration_ms']]
coef_corr = sub_df.corr()
print (round(coef_corr, 4))
# Out:
#              popularity  duration_ms
# popularity       1.0000       0.4257
# duration_ms      0.4257       1.0000

# %% [markdown]
# La relación entre duración y popularidad que se observa en el gráfico y el bajo nivel de correlacion entre las variables conduce a aceptar que existe una relación indepediente entre ambas barriables. Por tanto, la duración de una canción no tendría efectos sobre su popularidad.
